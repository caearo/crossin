# %%
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

from pyecharts.charts import Bar, Pie
from pyecharts import options as opts
 
# V1 版本开始支持链式调用
bar = (
    Bar()
    .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
    .add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
    .set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
)

# %%
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="747a2101d8474201880513546a37824f" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_747a2101d8474201880513546a37824f = echarts.init(
#             document.getElementById('747a2101d8474201880513546a37824f'), 'white', {renderer: 'canvas'});
#         var option_747a2101d8474201880513546a37824f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
# ...

# %%
import pandas as pd

# %%
#读取 Task_4_lianjia_sale.csv 数据(阅读参考文章 2、3)，利用 groupby 函数，以【区域】字段进行 groupby， 同时结合 agg 聚合函数统计各个区域平均房价;
#将统计所得平均房价命名为【区域平均价格】列 (阅读参考文章 4、5)
lianjia_data = pd.read_csv('./Task_4_lianjia_sale.csv')
#lianjia_data.groupby(['区域']).价格.agg([('区域平均价格', 'mean')])

#并将数据从小到大按顺序排列(提示:df.sort_values(by = “ ”) (阅读参考文章 6));
#lianjia_data.groupby(['区域']).价格.agg([('区域平均价格', 'mean')]).sort_values(by = '区域平均价格')

#最后展示所得前 5 行数据 (将所得的 DataFrame 命名为 df_avg);
df_avg = lianjia_data.groupby(['区域']).价格.agg([('区域平均价格', 'mean')]).sort_values(by = '区域平均价格')
# Out:
# ['金山',
#  '奉贤',
#  '松江',
#  '嘉定',
#  '青浦',
#  '宝山',
#  '闵行',
#  '浦东',
#  '普陀',
#  '杨浦',
#  '虹口',
#  '长宁',
#  '静安',
#  '徐汇',
#  '黄浦']

# %%
#利用 Pyecharts 将第(1)问所得数据作条形图(阅读参考文章 7)，图表标题为“上海各区域平均价格”(提示: 最后用 render_notebook()渲染显示出图片);
bar = (
    Bar()
    .add_xaxis(df_avg.index.tolist())
    .add_yaxis(df_avg.区域平均价格.name, df_avg.区域平均价格.tolist())
    #.set_series_opts(label_opts=opts.LabelOpts(formatter = '{c}'))
    .set_global_opts(title_opts=opts.TitleOpts(title = '上海各行政区平均价格'))
)

bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="e80905c14a0b4154a3679965aea234fc" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_e80905c14a0b4154a3679965aea234fc = echarts.init(
#             document.getElementById('e80905c14a0b4154a3679965aea234fc'), 'white', {renderer: 'canvas'});
#         var option_e80905c14a0b4154a3679965aea234fc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
# ...

# %%
#利用 groupby 函数，以【装修类型】字段进行 groupby，同时结合 agg 聚合函数统计各个区域房源数量;
#将统计所得数据命名为【房源数量】列;最后展示所得数据(将所得的 DataFrame 命名为 df_zhuangxiu);
df_zhuangxiu = lianjia_data.groupby(['装修类型']).房型.agg([('房源数量', 'count')])

# %%
#利用 Pyecharts 将第(3)问所得数据作饼图(阅读参考文章 7、8)，图表标题为“装修类型占比情况”
#(提示: v1=["啤酒","可乐","雪碧","咖啡","奶茶"] v2=[30,19,21,12,18]，a = [list(z) for z in zip(v1,v2)]， 则生成 v1 与 v2 一一对应的数据)。
pie_data = df_zhuangxiu.sort_values(by = '房源数量', ascending = False)
pie = (
    Pie()
    .add('', [list(z) for z in zip(pie_data.房源数量.index, pie_data.房源数量.tolist())])
    .set_series_opts(label_opts=opts.LabelOpts(formatter = "{b}:{c}({d}%)"))
    .set_global_opts(title_opts=opts.TitleOpts(title = '装修类型占比情况'))
)

pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="b49ce740efd84b06b8cf15264727c437" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_b49ce740efd84b06b8cf15264727c437 = echarts.init(
#             document.getElementById('b49ce740efd84b06b8cf15264727c437'), 'white', {renderer: 'canvas'});
#         var option_b49ce740efd84b06b8cf15264727c437 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
# ...
