# %%
import tushare as ts
import pandas as pd

# %%
from pyecharts.globals import CurrentConfig, NotebookType
#CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK

from pyecharts.charts import Map, Geo
from pyecharts import options as opts

# %%
# 读取数据，计算平均房价

lianjia_data = pd.read_csv('./Task_4_lianjia_sale.csv')

df_avg = lianjia_data.groupby(['区域']).价格.agg([('区域平均价格', 'mean')]).sort_values(by = '区域平均价格')
df_avg
# Out:
#           区域平均价格
# 区域
# 金山  19304.818824
# 奉贤  23662.131268
# 松江  36461.715479
# 嘉定  36587.687199
# 青浦  37078.860149
# 宝山  42577.796632
# 闵行  49080.587398
# 浦东  55413.057914
# 普陀  57943.126871
# 杨浦  62726.673854
# 虹口  66165.352834
# 长宁  72099.617088
# 静安  74304.768542
# 徐汇  75395.941983
# 黄浦  95015.086252

# %%
# 根据任务 4 所统计的上海各个区的房均价数据，利用 Pyecharts 中的 Map，以上海地图为背景作可视化展示图 
# (提示:可以直接定义 districts = ['金山区', '奉贤区', '嘉定区', '松江区', '青浦区', '宝山区', '闵行区 ', '浦东新区', '普陀区', 
# '杨浦区', '虹口区', '长宁区', '静安区', '徐汇区', '黄浦区'])(阅读参考文章 2);

#将数据处理成列表
locate = [i+'区' if i!='浦东' else i+'新区' for i in df_avg.index.tolist()]
price = df_avg.区域平均价格.tolist()
list_data = [[locate[i], price[i]] for i in range(len(locate))]

print(list_data)

m = (
    Map()
    .set_global_opts(
        title_opts=opts.TitleOpts(title="上海各行政区平均房价"),
        visualmap_opts=opts.VisualMapOpts(max_ = max(price))  #最大数据范围
    )
    .add("上海各行政区平均房价", list_data, maptype="上海")
)
#m.load_javascript()
m.render_notebook()
# Out:
# [['金山区', 19304.81882352941], ['奉贤区', 23662.131267605633], ['松江区', 36461.71547922952], ['嘉定区', 36587.68719889883], ['青浦区', 37078.86014935506], ['宝山区', 42577.79663212435], ['闵行区', 49080.58739837398], ['浦东新区', 55413.057913887205], ['普陀区', 57943.126870826614], ['杨浦区', 62726.67385444744], ['虹口区', 66165.35283446712], ['长宁区', 72099.61708770934], ['静安区', 74304.76854219948], ['徐汇区', 75395.94198264048], ['黄浦区', 95015.08625196027]]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '上海':'https://assets.pyecharts.org/assets/maps/shanghai'
#         }
#     });
# </script>
#
#         <div id="d60c7459807a4ff18c56baab7111c9eb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '上海'], function(echarts) {
#                 var chart_d60c7459807a4ff18c56baab7111c9eb = echarts.init(
# ...

# %%
#导入 tushare 数据包，提取 A 股基本数据信息，利用 groupby 函数统计每个省份的公司数量，并以中国地图 为背景作相应图表

stock = ts.get_stock_basics()
stock.head(2)
# Out:
#         name industry area      pe  outstanding  totals  totalAssets  \
# code
# 002255  海陆重工     专用机械   江苏   29.33         6.44    8.42        75.65
# 688166  博瑞医药     化学制药   江苏  332.24         0.37    4.10         9.19
#
#         liquidAssets  fixedAssets  reserved  ...  bvps     pb  timeToMarket  \
# code                                         ...
# 002255         51.33        14.63     21.57  ...  4.53   0.67      20080625
# 688166          5.80         2.20      3.02  ...  3.11  22.18      20191108
#
#         undp  perundp    rev  profit    gpr    npr  holders
# code
# 002255  7.17     0.85  31.67  -48.14  19.09   3.60  46829.0
# 688166  1.52     0.37   0.00    0.00  62.03  20.35  26778.0
#
# [2 rows x 22 columns]

# %%
# 整理数据并画图

df = stock.groupby(['area']).name.agg([('公司数', 'count')])
print(df.T)

m = (
    Map()
    .add('各省份公司数量', zip(df.index, df.公司数), maptype='china' )
    .set_global_opts (
        title_opts = opts.TitleOpts(title = 'A股公司数量分布'),
        visualmap_opts = opts.VisualMapOpts(max_ = max(df.公司数))
    )
)

m.render_notebook()
# Out:
# area   上海  云南  内蒙   北京  吉林   四川  天津  宁夏   安徽   山东  ...   湖南  甘肃   福建  西藏  贵州  \
# 公司数   306  36  25  350  42  126  54  14  107  209  ...  106  33  141  19  29
#
# area  辽宁  重庆  陕西  青海  黑龙江
# 公司数   74  53  53  12   38
#
# [1 rows x 32 columns]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="76dff31606c8402d981dc0b614896d5c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_76dff31606c8402d981dc0b614896d5c = echarts.init(
#                     document.getElementById('76dff31606c8402d981dc0b614896d5c'), 'white', {renderer: 'canvas'});
#                 var option_76dff31606c8402d981dc0b614896d5c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
# ...
